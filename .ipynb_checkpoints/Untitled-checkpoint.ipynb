# %%
# %run ./FPL_data_preprocessing.ipynb

# %%
var = %run ./FPL_main.ipynb
# Out:
# 1. Top Transfered In
# The above mentioned players are hot favorites by FPL managers. The reason can be player's form (good), easier upcoming fixtures, lower cost or sometimes can be cheapest idle bench.
#
#
# 2. Top Transfered Out
# The above mentioned players are most transferred out by FPL managers across the globe. Here, the reason behind their relatively less popularity can be degrading form, difficult fixtures, red card, injury or 3 players per EPL team constraint.
#
#
# 3. Most Selected
# The above list of players are present in most of the FPL manager's team. Here the most import features are consistent delivery and cost.
#
#
# 4. Top ICT Index (Influence - Creativity - Threat)
# '`ICT` is an important parameter for FPL managers to quantify player's performance.
#
# 1. `Influence`:
# Influence evaluates the degree to which a player has made an impact on a single match or throughout the season.
#
# 2. `Creativity`:
# ...

# %% [markdown]
# --------
