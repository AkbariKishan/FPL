# %%
# Dependencies

import pandas as pd
from fpl import formation, plot_players_img

# %%
# Reading dataset

players = pd.read_csv('fpl_data_processed.csv')
image_base = 'https://resources.premierleague.com/premierleague/photos/players/110x140/p'
base_url = 'https://fantasy.premierleague.com/api/'

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### 1. Transfer In-Out

# %%
# Top In

feaures_req = ['full_name', 'now_cost', 'photo', 'singular_name', 'influence', 'creativity',
           'threat', 'ict_index', 'minutes',
           'points_per_game', 'selected_by_percent', 'status',
           'club_name', 'next_1', 'next_2', 'next_3']

output = players.sort_values(by = 'transfers_in_event',
                    axis = 0,
                    ascending  = False).head(10)[feaures_req].reset_index(drop =True)

plot_players_img(output, image_base).plot()
output
# Out:
#                 full_name  now_cost   photo singular_name  influence  \
# 0            Demarai Gray       5.6  172632    Midfielder       94.4
# 1         Patrick Bamford       7.9  106617       Forward       53.0
# 2    Raphael Dias Belloli       6.5  219961    Midfielder       64.4
# 3  Richarlison de Andrade       7.5  212319       Forward       80.2
# 4  Allan Marques Loureiro       4.6  119765    Midfielder       82.4
# 5   Dominic Calvert-Lewin       8.2  177815       Forward      118.4
# 6             Luke Ayling       4.5   66588      Defender       93.4
# 7           Sam Greenwood       4.5  248937       Forward        0.0
# 8        Lewis Richardson       4.5  461096       Forward        0.0
# 9           Stuart Dallas       5.5   87873    Midfielder       59.6
#
#    creativity  threat  ict_index  minutes  points_per_game  \
# 0        56.0    68.0       21.9      244              6.3
# 1        26.4   149.0       22.7      256              4.7
# 2        73.9    88.0       22.7      270              3.3
# 3        72.6    93.0       24.5      268              4.7
# 4        61.2     7.0       15.0      270              4.0
# 5        39.8   178.0       33.7      248              7.7
# 6        21.2    21.0       13.5      270              3.0
# 7         0.0     0.0        0.0        0              0.0
# 8         0.0     0.0        0.0        0              0.0
# 9        43.0    12.0       11.5      270              3.0
#
#    selected_by_percent status club_name     next_1     next_2   next_3
# 0                 10.3      a   Everton    Burnley    Norwich  Man Utd
# 1                 11.8      a     Leeds  Liverpool   West Ham  Watford
# 2                 15.2      a     Leeds  Liverpool   West Ham  Watford
# 3                 12.1      a   Everton    Burnley    Norwich  Man Utd
# 4                  6.2      a   Everton    Burnley    Norwich  Man Utd
# 5                 14.3      d   Everton    Burnley    Norwich  Man Utd
# 6                 12.4      a     Leeds  Liverpool   West Ham  Watford
# 7                  1.8      a     Leeds  Liverpool   West Ham  Watford
# 8                  1.1      a   Burnley    Everton  Leicester  Norwich
# 9                 10.2      a     Leeds  Liverpool   West Ham  Watford

# %%
# Top Out

output = players.sort_values(by = 'transfers_out_event',
                    axis = 0,
                    ascending  = False).head(10)[feaures_req].reset_index(drop =True)

plot_players_img(output, image_base).plot()
output
# Out:
#                 full_name  now_cost   photo singular_name  influence  \
# 0   Dominic Calvert-Lewin       8.2  177815       Forward      118.4
# 1  Richarlison de Andrade       7.5  212319       Forward       80.2
# 2         Patrick Bamford       7.9  106617       Forward       53.0
# 3             Lucas Digne       5.4  101188      Defender       27.0
# 4    Raphael Dias Belloli       6.5  219961    Midfielder       64.4
# 5           Stuart Dallas       5.5   87873    Midfielder       59.6
# 6             Luke Ayling       4.5   66588      Defender       93.4
# 7            Demarai Gray       5.6  172632    Midfielder       94.4
# 8         Jordan Pickford       5.0  111234    Goalkeeper       48.2
# 9  Allan Marques Loureiro       4.6  119765    Midfielder       82.4
#
#    creativity  threat  ict_index  minutes  points_per_game  \
# 0        39.8   178.0       33.7      248              7.7
# 1        72.6    93.0       24.5      268              4.7
# 2        26.4   149.0       22.7      256              4.7
# 3        79.8    21.0       12.8      270              2.7
# 4        73.9    88.0       22.7      270              3.3
# 5        43.0    12.0       11.5      270              3.0
# 6        21.2    21.0       13.5      270              3.0
# 7        56.0    68.0       21.9      244              6.3
# 8        10.0     0.0        5.9      270              3.0
# 9        61.2     7.0       15.0      270              4.0
#
#    selected_by_percent status club_name     next_1    next_2   next_3
# 0                 14.3      d   Everton    Burnley   Norwich  Man Utd
# 1                 12.1      a   Everton    Burnley   Norwich  Man Utd
# 2                 11.8      a     Leeds  Liverpool  West Ham  Watford
# 3                 13.2      a   Everton    Burnley   Norwich  Man Utd
# 4                 15.2      a     Leeds  Liverpool  West Ham  Watford
# 5                 10.2      a     Leeds  Liverpool  West Ham  Watford
# 6                 12.4      a     Leeds  Liverpool  West Ham  Watford
# 7                 10.3      a   Everton    Burnley   Norwich  Man Utd
# 8                  7.5      a   Everton    Burnley   Norwich  Man Utd
# 9                  6.2      a   Everton    Burnley   Norwich  Man Utd

# %% [markdown]
# ### 2. Most Selected

# %%
players.selected_by_percent = players.selected_by_percent.astype('float64')
players.sort_values('selected_by_percent', ascending=False)[feaures_req].head(10).reset_index(drop=True)
# Out:
#                 full_name  now_cost   photo singular_name  influence  \
# 0    Raphael Dias Belloli       6.5  219961    Midfielder       64.4
# 1   Dominic Calvert-Lewin       8.2  177815       Forward      118.4
# 2             Lucas Digne       5.4  101188      Defender       27.0
# 3             Luke Ayling       4.5   66588      Defender       93.4
# 4  Richarlison de Andrade       7.5  212319       Forward       80.2
# 5         Patrick Bamford       7.9  106617       Forward       53.0
# 6            Demarai Gray       5.6  172632    Midfielder       94.4
# 7           Stuart Dallas       5.5   87873    Midfielder       59.6
# 8         Jordan Pickford       5.0  111234    Goalkeeper       48.2
# 9  Allan Marques Loureiro       4.6  119765    Midfielder       82.4
#
#    creativity  threat  ict_index  minutes  points_per_game  \
# 0        73.9    88.0       22.7      270              3.3
# 1        39.8   178.0       33.7      248              7.7
# 2        79.8    21.0       12.8      270              2.7
# 3        21.2    21.0       13.5      270              3.0
# 4        72.6    93.0       24.5      268              4.7
# 5        26.4   149.0       22.7      256              4.7
# 6        56.0    68.0       21.9      244              6.3
# 7        43.0    12.0       11.5      270              3.0
# 8        10.0     0.0        5.9      270              3.0
# 9        61.2     7.0       15.0      270              4.0
#
#    selected_by_percent status club_name     next_1    next_2   next_3
# 0                 15.2      a     Leeds  Liverpool  West Ham  Watford
# 1                 14.3      d   Everton    Burnley   Norwich  Man Utd
# 2                 13.2      a   Everton    Burnley   Norwich  Man Utd
# 3                 12.4      a     Leeds  Liverpool  West Ham  Watford
# 4                 12.1      a   Everton    Burnley   Norwich  Man Utd
# 5                 11.8      a     Leeds  Liverpool  West Ham  Watford
# 6                 10.3      a   Everton    Burnley   Norwich  Man Utd
# 7                 10.2      a     Leeds  Liverpool  West Ham  Watford
# 8                  7.5      a   Everton    Burnley   Norwich  Man Utd
# 9                  6.2      a   Everton    Burnley   Norwich  Man Utd

# %% [markdown]
# ### 3. Top 11 Formation
# (Without 3 players per team rule and without upper buy cap)

# %%
# Defining best formation based on points

team_3_4_3_1 = formation(players, 3,4,3,1).players()
team_3_3_4_1 = formation(players, 3,3,4,1).players()
team_2_5_3_1 = formation(players, 2,5,3,1).players()
team_2_3_5_1 = formation(players, 2,3,5,1).players()
team_2_4_4_1 = formation(players, 2,4,4,1).players()
team_1_4_5_1 = formation(players, 1,4,5,1).players()
team_1_5_4_1 = formation(players, 1,5,4,1).players()


team_3_4_3_1_avg = team_3_4_3_1.points_per_game.mean()
team_3_3_4_1_avg = team_3_3_4_1.points_per_game.mean()
team_2_5_3_1_avg = team_2_5_3_1.points_per_game.mean()
team_2_3_5_1_avg = team_2_3_5_1.points_per_game.mean()
team_2_4_4_1_avg = team_2_4_4_1.points_per_game.mean()
team_1_4_5_1_avg = team_1_4_5_1.points_per_game.mean()
team_1_5_4_1_avg = team_1_5_4_1.points_per_game.mean()

req_dict = {'team_3_4_3_1':team_3_4_3_1_avg, 'team_3_3_4_1':team_3_3_4_1_avg, 
            'team_2_5_3_1':team_2_5_3_1_avg, 'team_2_3_5_1':team_2_3_5_1_avg, 'team_2_4_4_1':team_2_4_4_1_avg, 
            'team_1_4_5_1':team_1_4_5_1_avg, 'team_1_5_4_1':team_1_5_4_1_avg}

max_key = max(req_dict, key=req_dict.get)
print('Best 11 formation:', max_key)

forwd = int(max_key.split('_')[1])
midfl = int(max_key.split('_')[2])
defed = int(max_key.split('_')[3])
# Out:
# Best 11 formation: team_3_4_3_1

# %%
# Plotting best formation

plot_players_img(formation(players, forwd,midfl,defed,1).players(), image_base).plot()
# Out:
# <module 'matplotlib.pyplot' from '/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ---------
